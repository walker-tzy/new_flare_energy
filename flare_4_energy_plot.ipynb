# %%
import datetime
import time
import xlrd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x_B= np.genfromtxt('xrs_B.csv', delimiter=',', skip_header=False)
y_B= np.genfromtxt('lya_B.csv', delimiter=',', skip_header=False)

x_C= np.genfromtxt('xrs_C.csv', delimiter=',', skip_header=False)
y_C= np.genfromtxt('lya_C.csv', delimiter=',', skip_header=False)

x_M= np.genfromtxt('xrs_M.csv', delimiter=',', skip_header=False)
y_M= np.genfromtxt('lya_M.csv', delimiter=',', skip_header=False)

x_X= np.genfromtxt('xrs_X.csv', delimiter=',', skip_header=False)
y_X= np.genfromtxt('lya_X.csv', delimiter=',', skip_header=False)




#x2=[10**(0),10**(7)]
#y2=[10**(0),10**(7)]

x3=[10**(0),10**(6)]
y3=[10**(1),10**(7)]

x4=[10**(0),10**(5)]
y4=[10**(2),10**(7)]

x5=[10**(0),10**(4)]
y5=[10**(3),10**(7)]

x6=[10**(0),10**(7)]
y6=[10**(0),10**(7)]


plt.figure(figsize=(9, 9))
#plt.scatter(x, y)

x_new_B = np.divide(x_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_B = np.divide(y_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_C = np.divide(x_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_C = np.divide(y_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_M = np.divide(x_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_M = np.divide(y_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_X = np.divide(x_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_X = np.divide(y_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

plt.loglog(x_new_B, y_new_B,'go',markerfacecolor='none',label=r'$B-class$')
plt.loglog(x_new_C, y_new_C,'ko',alpha=0.6,markerfacecolor='none',label=r'$C-class$',marker='D',markeredgecolor='k')
plt.loglog(x_new_M, y_new_M,'bo',alpha=0.6,markerfacecolor='none',label=r'$M-class$',marker='D',markeredgecolor='b')
plt.loglog(x_new_X, y_new_X,'ro',markerfacecolor=None,label=r'$X-class$',markeredgecolor='r')
#plt.loglog(x1,y1,'r.',label=r'$C-class$')

#plt.plot(x2,y2,'--',color='black')
plt.plot(x3,y3,'-.',color='black')
plt.plot(x4,y4,'--',color='black')
plt.plot(x5,y5,':',color='black')
plt.plot(x6,y6,'-',color='black')
#plt.plot(x6,y6,'--',color='black')

plt.ylim(10**(0),10**(7))
plt.xlim(10**(0),10**(7))
#Plot.xlim(10**(5), 10**(6));Plot.ylim(10**(5), 10**(6))

x_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
x_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.xticks(x_ticks,x_name)  #设置坐标刻度

y_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
y_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.yticks(y_ticks,y_name)  #设置坐标刻度


plt.xlabel(r'$1-8{A} \quad X-ray \quad Energy \quad (erg)$')
plt.ylabel(r'$Lyα \quad Energy \quad (erg)$')
plt.legend() #图例
plt.savefig('all_energy.png', format='png', bbox_inches='tight',dpi=600)
plt.show()

# %%
import datetime
import time
import xlrd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x_B= np.genfromtxt('xrs_B.csv', delimiter=',', skip_header=False)
y_B= np.genfromtxt('lya_B.csv', delimiter=',', skip_header=False)

x_C= np.genfromtxt('xrs_C.csv', delimiter=',', skip_header=False)
y_C= np.genfromtxt('lya_C.csv', delimiter=',', skip_header=False)

x_M= np.genfromtxt('xrs_M.csv', delimiter=',', skip_header=False)
y_M= np.genfromtxt('lya_M.csv', delimiter=',', skip_header=False)

x_X= np.genfromtxt('xrs_X.csv', delimiter=',', skip_header=False)
y_X= np.genfromtxt('lya_X.csv', delimiter=',', skip_header=False)




#x2=[10**(0),10**(7)]
#y2=[10**(0),10**(7)]

x3=[10**(0),10**(6)]
y3=[10**(1),10**(7)]

x4=[10**(0),10**(5)]
y4=[10**(2),10**(7)]

x5=[10**(0),10**(4)]
y5=[10**(3),10**(7)]

x6=[10**(0),10**(7)]
y6=[10**(0),10**(7)]


plt.figure(figsize=(9, 9))
#plt.scatter(x, y)

x_new_B = np.divide(x_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_B = np.divide(y_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_C = np.divide(x_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_C = np.divide(y_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_M = np.divide(x_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_M = np.divide(y_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_X = np.divide(x_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_X = np.divide(y_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

#plt.loglog(x_new_B, y_new_B,'go',markerfacecolor='none',label=r'$B-class$')
#plt.loglog(x_new_C, y_new_C,'ko',alpha=0.6,markerfacecolor='none',label=r'$C-class$',marker='D',markeredgecolor='k')
plt.loglog(x_new_M, y_new_M,'bo',alpha=0.6,markerfacecolor='none',label=r'$M-class$',marker='D',markeredgecolor='b')
plt.loglog(x_new_X, y_new_X,'ro',markerfacecolor=None,label=r'$X-class$',markeredgecolor='r')
#plt.loglog(x1,y1,'r.',label=r'$C-class$')

#plt.plot(x2,y2,'--',color='black')
plt.plot(x3,y3,'-.',color='black')
plt.plot(x4,y4,'--',color='black')
plt.plot(x5,y5,':',color='black')
plt.plot(x6,y6,'-',color='black')
#plt.plot(x6,y6,'--',color='black')

plt.ylim(10**(0),10**(7))
plt.xlim(10**(0),10**(7))
#Plot.xlim(10**(5), 10**(6));Plot.ylim(10**(5), 10**(6))

x_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
x_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.xticks(x_ticks,x_name)  #设置坐标刻度

y_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
y_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.yticks(y_ticks,y_name)  #设置坐标刻度


plt.xlabel(r'$1-8{A} \quad X-ray \quad Energy \quad (erg)$')
plt.ylabel(r'$Lyα \quad Energy \quad (erg)$')
plt.legend() #图例
plt.savefig('M_X_energy.png', format='png', bbox_inches='tight',dpi=600)
plt.show()

# %%
import datetime
import time
import xlrd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x_B= np.genfromtxt('xrs_B.csv', delimiter=',', skip_header=False)
y_B= np.genfromtxt('lya_B.csv', delimiter=',', skip_header=False)

x_C= np.genfromtxt('xrs_C.csv', delimiter=',', skip_header=False)
y_C= np.genfromtxt('lya_C.csv', delimiter=',', skip_header=False)

x_M= np.genfromtxt('xrs_M.csv', delimiter=',', skip_header=False)
y_M= np.genfromtxt('lya_M.csv', delimiter=',', skip_header=False)

x_X= np.genfromtxt('xrs_X.csv', delimiter=',', skip_header=False)
y_X= np.genfromtxt('lya_X.csv', delimiter=',', skip_header=False)




#x2=[10**(0),10**(7)]
#y2=[10**(0),10**(7)]

x3=[10**(0),10**(6)]
y3=[10**(1),10**(7)]

x4=[10**(0),10**(5)]
y4=[10**(2),10**(7)]

x5=[10**(0),10**(4)]
y5=[10**(3),10**(7)]

x6=[10**(0),10**(7)]
y6=[10**(0),10**(7)]


plt.figure(figsize=(9, 9))
#plt.scatter(x, y)

x_new_B = np.divide(x_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_B = np.divide(y_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_C = np.divide(x_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_C = np.divide(y_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_M = np.divide(x_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_M = np.divide(y_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_X = np.divide(x_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_X = np.divide(y_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

#plt.loglog(x_new_B, y_new_B,'go',markerfacecolor='none',label=r'$B-class$')
plt.loglog(x_new_C, y_new_C,'ko',alpha=0.6,markerfacecolor='none',label=r'$C-class$',marker='D',markeredgecolor='k')
#plt.loglog(x_new_M, y_new_M,'bo',alpha=0.6,markerfacecolor='none',label=r'$M-class$',marker='D',markeredgecolor='b')
#plt.loglog(x_new_X, y_new_X,'ro',markerfacecolor=None,label=r'$X-class$',markeredgecolor='r')
#plt.loglog(x1,y1,'r.',label=r'$C-class$')

#plt.plot(x2,y2,'--',color='black')
plt.plot(x3,y3,'-.',color='black')
plt.plot(x4,y4,'--',color='black')
plt.plot(x5,y5,':',color='black')
plt.plot(x6,y6,'-',color='black')
#plt.plot(x6,y6,'--',color='black')

plt.ylim(10**(0),10**(7))
plt.xlim(10**(0),10**(7))
#Plot.xlim(10**(5), 10**(6));Plot.ylim(10**(5), 10**(6))

x_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
x_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.xticks(x_ticks,x_name)  #设置坐标刻度

y_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
y_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.yticks(y_ticks,y_name)  #设置坐标刻度


plt.xlabel(r'$1-8{A} \quad X-ray \quad Energy \quad (erg)$')
plt.ylabel(r'$Lyα \quad Energy \quad (erg)$')
plt.legend() #图例
plt.savefig('C_energy.png', format='png', bbox_inches='tight',dpi=600)
plt.show()

# %%
import datetime
import time
import xlrd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x_B= np.genfromtxt('xrs_B.csv', delimiter=',', skip_header=False)
y_B= np.genfromtxt('lya_B.csv', delimiter=',', skip_header=False)

x_C= np.genfromtxt('xrs_C.csv', delimiter=',', skip_header=False)
y_C= np.genfromtxt('lya_C.csv', delimiter=',', skip_header=False)

x_M= np.genfromtxt('xrs_M.csv', delimiter=',', skip_header=False)
y_M= np.genfromtxt('lya_M.csv', delimiter=',', skip_header=False)

x_X= np.genfromtxt('xrs_X.csv', delimiter=',', skip_header=False)
y_X= np.genfromtxt('lya_X.csv', delimiter=',', skip_header=False)




#x2=[10**(0),10**(7)]
#y2=[10**(0),10**(7)]

x3=[10**(0),10**(6)]
y3=[10**(1),10**(7)]

x4=[10**(0),10**(5)]
y4=[10**(2),10**(7)]

x5=[10**(0),10**(4)]
y5=[10**(3),10**(7)]

x6=[10**(0),10**(7)]
y6=[10**(0),10**(7)]


plt.figure(figsize=(9, 9))
#plt.scatter(x, y)

x_new_B = np.divide(x_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_B = np.divide(y_B, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_C = np.divide(x_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_C = np.divide(y_C, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_M = np.divide(x_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_M = np.divide(y_M, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

x_new_X = np.divide(x_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴
y_new_X = np.divide(y_X, 10**(25))  #缩小量级，后续坐标轴重新定义坐标轴

plt.loglog(x_new_B, y_new_B,'go',markerfacecolor='none',label=r'$B-class$')
#plt.loglog(x_new_C, y_new_C,'ko',alpha=0.6,markerfacecolor='none',label=r'$C-class$',marker='D',markeredgecolor='k')
#plt.loglog(x_new_M, y_new_M,'bo',alpha=0.6,markerfacecolor='none',label=r'$M-class$',marker='D',markeredgecolor='b')
#plt.loglog(x_new_X, y_new_X,'ro',markerfacecolor=None,label=r'$X-class$',markeredgecolor='r')
#plt.loglog(x1,y1,'r.',label=r'$C-class$')

#plt.plot(x2,y2,'--',color='black')
plt.plot(x3,y3,'-.',color='black')
plt.plot(x4,y4,'--',color='black')
plt.plot(x5,y5,':',color='black')
plt.plot(x6,y6,'-',color='black')
#plt.plot(x6,y6,'--',color='black')

plt.ylim(10**(0),10**(7))
plt.xlim(10**(0),10**(7))
#Plot.xlim(10**(5), 10**(6));Plot.ylim(10**(5), 10**(6))

x_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
x_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.xticks(x_ticks,x_name)  #设置坐标刻度

y_ticks = [10**(0),10**(1),10**(2),10**(3),10**(4),10**(5),10**(6),10**(7)]#用10^0来代替10^25，因为直接显示不了这么大
y_name = [r'$10^{25}$',r'$10^{26}$',r'$10^{27}$',r'$10^{28}$',r'$10^{29}$',r'$10^{30}$',r'$10^{31}$',r'$10^{32}$']
plt.yticks(y_ticks,y_name)  #设置坐标刻度


plt.xlabel(r'$1-8{A} \quad X-ray \quad Energy \quad (erg)$')
plt.ylabel(r'$Lyα \quad Energy \quad (erg)$')
plt.legend() #图例
plt.savefig('B_energy.png', format='png', bbox_inches='tight',dpi=600)
plt.show()
